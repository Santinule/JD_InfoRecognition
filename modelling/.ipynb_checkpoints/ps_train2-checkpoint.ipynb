# %%
import pandas as pd
import numpy as np
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from preprocess import preprocess_text

# %%
df = pd.read_csv("../../data/jdCleanData/pst2_df.csv")
# Load a SpaCy model
nlp = spacy.load('en_core_web_lg')

# %%
# Out:
#         dsm                                               text  \
# 0  10000400                                  Position Summary:
# 1  10000400  The VP/Chief Financial Officer for Johns Hopki...
# 2  10000400  Development, oversight and review of the budge...
# 3  10000400  Internal and external financial analysis and r...
# 4  10000400  Production and maintenance of the monthly fina...
#
#    previous_column_number  str_len  is_ps  entity_encode  \
# 0                       3       17      1             10
# 1                       4      557      1             10
# 2                       5      118      1             10
# 3                       6       55      1             10
# 4                       7       94      1             10
#
#                                             lag_text  \
# 0                                           line one
# 1                                  Position Summary:
# 2  The VP/Chief Financial Officer for Johns Hopki...
# 3  Development, oversight and review of the budge...
# 4  Internal and external financial analysis and r...
#
#                                            lag_text2  \
# 0                                           line two
# 1                                           line one
# 2                                  Position Summary:
# 3  The VP/Chief Financial Officer for Johns Hopki...
# 4  Development, oversight and review of the budge...
#
#                                            lead_text  \
# 0  The VP/Chief Financial Officer for Johns Hopki...
# 1  Development, oversight and review of the budge...
# 2  Internal and external financial analysis and r...
# 3  Production and maintenance of the monthly fina...
# 4  Support the financial operations of JHI’s fore...
#
#                                           lead_text2
# 0  Development, oversight and review of the budge...
# 1  Internal and external financial analysis and r...
# 2  Production and maintenance of the monthly fina...
# 3  Support the financial operations of JHI’s fore...
# 4  New and existing project / program / product d...

# %%
# Apply the function to the 'previous_line' column
columns_to_preprocess = ['text', 'lag_text','lag_text2', 'lead_text', 'lead_text2']

for column in columns_to_preprocess:
    df[column] = df[column].apply(lambda x:preprocess_text(x, nlp))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer


# Define preprocessor
preprocessor_ps2 = ColumnTransformer(
    transformers=[
        ('text', CountVectorizer(), 'text'),
        ('lag_text', CountVectorizer(), 'lag_text'),
        ('lag_text2', CountVectorizer(), 'lag_text2'),
        ('lead_text', CountVectorizer(), 'lead_text'),
        ('lead_text2', CountVectorizer(), 'lead_text2'),
        ('num', StandardScaler(with_mean=False), ['str_len']),
        ('cat', OneHotEncoder(handle_unknown='ignore'), ['entity_encode'])
    ]
)

X = df[["text", 'previous_column_number', 'str_len',
        "lag_text", 'lag_text2',
        'lead_text','lead_text2',
        'entity_encode']]

y = df['is_ps']

# Fit and transform the data
X = preprocessor_ps2.fit_transform(X)
from joblib import dump
dump(preprocessor_ps2, 'preprocessors/ps_processor.joblib')
print(df.dtypes)
# Out:
# dsm                        int64
# text                      object
# previous_column_number     int64
# str_len                    int64
# is_ps                      int64
# entity_encode              int64
# lag_text                  object
# lag_text2                 object
# lead_text                 object
# lead_text2                object
# dtype: object

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=20)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.semi_supervised import SelfTrainingClassifier
from sklearn.model_selection import GridSearchCV

# Defining base classifier
base_classifier = RandomForestClassifier()

# Wrap it with SelfTrainingClassifier
self_training_clf = SelfTrainingClassifier(base_classifier)

# Parameters for GridSearch. Notice the prefix to each parameter which corresponds to the base_classifier.
param_grid = {
    'base_estimator__n_estimators': [50, 100, 150],
    'base_estimator__max_depth': [None, 5, 10, 12],
    'base_estimator__min_samples_split': [2, 5, 10],
    'base_estimator__min_samples_leaf': [1, 2, 4],
    'base_estimator__bootstrap': [True, False]
}

# Setting up GridSearch with Cross-Validation
grid_search = GridSearchCV(estimator=self_training_clf, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time= 8.5min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time= 4.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time= 8.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time= 4.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time= 8.0min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time= 3.8min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time= 7.5min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time= 3.7min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time= 7.5min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time= 3.6min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time= 7.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time= 3.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time= 6.6min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time= 3.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time= 6.5min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time= 3.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time= 6.6min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=  14.6s
# /Users/santinule/Library/Python/3.9/lib/python/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time= 4.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=12.7min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=12.5min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=12.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=11.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=11.0min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=11.0min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 8.8min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 9.8min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 7.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  44.8s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 1.4min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 1.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 1.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  45.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=  28.6s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time= 4.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=12.7min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=12.7min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 9.9min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=11.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=11.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=11.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 9.9min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 9.9min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=10.0min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 1.4min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 1.0min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 1.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 1.4min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time= 8.5min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time= 4.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time= 8.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time= 4.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time= 8.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time= 3.7min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time= 7.4min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time= 3.8min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time= 7.4min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time= 3.7min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time= 7.4min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time= 3.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time= 6.5min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time= 3.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time= 4.7min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 9.8min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   5.0s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   6.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   5.3s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   6.7s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   5.5s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  13.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  11.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  16.3s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  15.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=   6.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=   7.5s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=   9.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=  18.6s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=   7.6s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  12.6s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=  22.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  17.6s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  22.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=  10.3s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=  22.5s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  12.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=  18.5s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=   9.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  14.7s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=   4.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=   6.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=   9.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=  14.7s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=   6.3s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=   6.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  12.3s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=  18.6s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  28.0s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 1.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=  56.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 1.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 1.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 1.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 1.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 1.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 1.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 1.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 1.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 1.4min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time= 1.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=  31.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time= 1.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  33.0s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time= 1.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=  26.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 1.7min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 1.6min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 1.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 1.6min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 1.6min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=15.0min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=   4.8s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=   9.7s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=  18.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   5.0s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=   9.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  14.6s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=   7.5s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=   7.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=  13.0s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=  14.6s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=   4.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=   4.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  12.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=  14.5s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   4.8s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=   9.7s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  18.3s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=   6.1s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=  14.7s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=  18.3s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=   6.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  12.1s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  22.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  39.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 1.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=  54.1s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=  28.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  51.7s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  29.5s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  56.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=  27.8s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=  40.7s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=  20.6s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  40.7s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  28.3s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  28.1s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  51.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=  48.5s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=  26.8s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  53.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  33.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  59.0s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=  32.3s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time= 1.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=  34.5s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time= 1.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  31.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 1.6min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 1.6min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 1.5min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time= 1.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=  31.7s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 1.6min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 1.6min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=14.8min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time= 7.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time= 8.6min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time= 4.1min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time= 8.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time= 4.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time= 8.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time= 3.7min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time= 7.4min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time= 3.7min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time= 7.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time= 3.7min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time= 7.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time= 3.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time= 6.6min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time= 3.3min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time= 5.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time= 3.2min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time= 6.6min
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  11.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  16.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  19.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=   7.5s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=   9.8s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=  14.7s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=   5.0s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=   6.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  12.8s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=  11.5s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   5.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   5.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  12.6s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  18.7s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=   5.1s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=  12.8s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=  11.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=   6.3s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=   7.6s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=   9.8s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=  22.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   7.5s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  12.3s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  14.6s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=   4.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=  12.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=  18.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=   9.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=  10.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  27.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  55.7s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=  28.1s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=  27.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=  54.3s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=  25.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  57.4s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  29.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  54.3s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=  56.6s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=  25.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  57.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  27.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  55.0s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=  26.8s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=  50.8s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  53.9s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=  58.2s
# [CV] END base_estimator__bootstrap=True, base_estimator__max_depth=12, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 1.6min
# ...
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=12, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 2.3min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=12, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 2.3min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=12, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 2.1min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=14.6min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time= 7.2min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=14.3min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time= 6.4min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=12.9min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time= 6.4min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=12.8min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time= 6.5min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=12.7min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time= 5.7min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=11.3min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time= 5.6min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=11.5min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time= 5.7min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=None, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=10.4min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   5.2s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   7.0s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   8.8s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  10.6s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   8.8s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  13.9s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  17.9s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  17.6s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  26.4s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=   9.0s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=   8.8s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=  17.6s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=  32.3s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  23.5s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=  22.4s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   9.2s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  23.0s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  27.8s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=   7.0s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=  17.6s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=  26.2s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=   8.8s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  21.0s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=  26.3s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=   7.3s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  14.0s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time=  27.7s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=   7.4s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time=  14.5s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time=  27.5s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=   8.8s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time=  25.2s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=5, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time=  21.0s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  40.3s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time=  42.5s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 1.8min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time= 1.3min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=  32.5s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time= 1.3min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  32.6s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time= 1.3min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=  39.9s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=100; total time= 1.3min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=50; total time=  35.7s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time= 1.3min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=50; total time=  39.5s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=100; total time= 1.2min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=50; total time=  39.4s
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 1.2min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=100; total time= 1.3min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=10, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 2.0min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=12, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 2.4min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=12, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 2.4min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=12, base_estimator__min_samples_leaf=1, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 1.9min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=12, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 2.4min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=12, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 2.4min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=12, base_estimator__min_samples_leaf=2, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 2.1min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=12, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=2, base_estimator__n_estimators=150; total time= 2.3min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=12, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=5, base_estimator__n_estimators=150; total time= 2.1min
# [CV] END base_estimator__bootstrap=False, base_estimator__max_depth=12, base_estimator__min_samples_leaf=4, base_estimator__min_samples_split=10, base_estimator__n_estimators=150; total time= 2.1min
# GridSearchCV(cv=5,
#              estimator=SelfTrainingClassifier(base_estimator=RandomForestClassifier()),
#              n_jobs=-1,
#              param_grid={'base_estimator__bootstrap': [True, False],
#                          'base_estimator__max_depth': [None, 5, 10, 12],
#                          'base_estimator__min_samples_leaf': [1, 2, 4],
#                          'base_estimator__min_samples_split': [2, 5, 10],
#                          'base_estimator__n_estimators': [50, 100, 150]},
#              verbose=2)

# %%
# Extracting the best parameters
best_params = grid_search.best_params_
print("Best hyperparameters:", best_params)
# Out:
# Best hyperparameters: {'base_estimator__bootstrap': False, 'base_estimator__max_depth': None, 'base_estimator__min_samples_leaf': 1, 'base_estimator__min_samples_split': 2, 'base_estimator__n_estimators': 150}

# %%
# Training the model with the best hyperparameters
model_for_eval = SelfTrainingClassifier(
    RandomForestClassifier(
        n_estimators=150,
        max_depth=None,
        min_samples_split=2,
        min_samples_leaf=1,
        bootstrap=False
    )
)

model_for_eval.fit(X_train, y_train)
# Out:
# SelfTrainingClassifier(base_estimator=RandomForestClassifier(bootstrap=False,
#                                                              n_estimators=150))

# %%
# Predicting with the model
y_pred = model_for_eval.predict(X_test)


from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
print("Accuracy:", accuracy_score(y_test, y_pred), "\n")
print(classification_report(y_test, y_pred), "\n")
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.8259025724010937
#
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00      2902
#            0       0.82      1.00      0.90     13807
#            1       0.84      0.83      0.84      1212
#
#     accuracy                           0.83     17921
#    macro avg       0.56      0.61      0.58     17921
# weighted avg       0.69      0.83      0.75     17921
#
#
# Confusion Matrix:
# [[    0  2727   175]
#  [    0 13797    10]
#  [    0   208  1004]]
# /Users/santinule/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/santinule/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/santinule/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Use all data to train model

# Training the model with the best hyperparameters


best_model_ps2 = model_for_eval.fit(X, y)

# %%
from joblib import dump

# Save the model using joblib
dump(best_model_ps2, '../../joblib/best_model_ps2.joblib')
# Out:
# ['../../joblib/best_model_ps2.joblib']
