# %%
import pandas as pd
import numpy as np
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from preprocess import preprocess_text

# %%
df= pd.read_csv("../../data/jdCleanData/pst_df.csv")
# Load a SpaCy model
nlp = spacy.load('en_core_web_lg')

# %%
# Out:
#         dsm                                               text  \
# 0  11432511                                            SUMMARY
# 1  11432511  This is a Bilingual Receptionist position with...
# 2  11432511                                ESSENTIAL FUNCTIONS
# 3  11432511  Reasonable accommodations may be made to enabl...
# 4  11432511  Responsible for communication with non-English...
#
#    previous_column_number  str_len  is_ps entity_encode  \
# 0                       2        7     -1            11
# 1                       3      415      1            11
# 2                       4       19      0            11
# 3                       5      103      0            11
# 4                       6      159      0            11
#
#                                             lag_text  \
# 0                                         first line
# 1                                            SUMMARY
# 2  This is a Bilingual Receptionist position with...
# 3                                ESSENTIAL FUNCTIONS
# 4  Reasonable accommodations may be made to enabl...
#
#                                            lag_text2  \
# 0                                        second line
# 1                                         first line
# 2                                            SUMMARY
# 3  This is a Bilingual Receptionist position with...
# 4                                ESSENTIAL FUNCTIONS
#
#                                            lag_text3    lag_text4
# 0                                         third line  fourth line
# 1                                        second line   third line
# 2                                         first line  second line
# 3                                            SUMMARY   first line
# 4  This is a Bilingual Receptionist position with...      SUMMARY

# %%
# Apply the function to the 'previous_line' column
columns_to_preprocess = ['text', 'lag_text', 'lag_text2', 'lag_text3']

for column in columns_to_preprocess:
    df[column] = df[column].apply(lambda x:preprocess_text(x, nlp))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer


# Define preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('text', CountVectorizer(), 'text'),
        ('lag_text', CountVectorizer(), 'lag_text'),
        ('lag_text2', CountVectorizer(), 'lag_text2'),
        ('lag_text3', CountVectorizer(), 'lag_text3'),
        ('num', StandardScaler(with_mean=False), ['str_len']),
        ('cat', OneHotEncoder(handle_unknown='ignore'), ['entity_encode'])
    ]
)

X = df[["text", 'previous_column_number', 'str_len', "lag_text", 'lag_text2', 'lag_text3', 'entity_encode']]
y = df['is_ps']

# Fit and transform the data
X = preprocessor.fit_transform(X)

# %%
from joblib import dump
dump(preprocessor, 'preprocessors/ps_processor.joblib')
print(df.dtypes)
# Out:
# dsm                       object
# text                      object
# previous_column_number     int64
# str_len                    int64
# is_ps                      int64
# entity_encode             object
# lag_text                  object
# lag_text2                 object
# lag_text3                 object
# lag_text4                 object
# dtype: object

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=20)

# %%
from sklearn.svm import SVC
from sklearn.semi_supervised import SelfTrainingClassifier
class_weight = {0: 1, 1: 4}

# %%
from sklearn.model_selection import GridSearchCV


# define the parameter values that should be searched
param_grid = {'base_estimator__C': [0.1, 1, 10, 100, 1000], 
              'base_estimator__gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'base_estimator__kernel': ['rbf'], 
              'base_estimator__class_weight': [class_weight]} 

base_classifier = SVC(probability=True)
self_training_model = SelfTrainingClassifier(base_classifier)

grid = GridSearchCV(self_training_model, param_grid, refit=True, verbose=3)

grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [69], line 15
#      11 self_training_model = SelfTrainingClassifier(base_classifier)
#      13 grid = GridSearchCV(self_training_model, param_grid, refit=True, verbose=3)
# ---> 15 grid.fit(X_train, y_train)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:1379, in GridSearchCV._run_search(self, evaluate_candidates)
#    1377 def _run_search(self, evaluate_candidates):
#    1378     """Search all candidates in param_grid"""
# -> 1379     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/joblib/parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File ~/Library/Python/3.9/lib/python/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/Library/Python/3.9/lib/python/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/Library/Python/3.9/lib/python/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/Library/Python/3.9/lib/python/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/Library/Python/3.9/lib/python/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/Library/Python/3.9/lib/python/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/semi_supervised/_self_training.py:234, in SelfTrainingClassifier.fit(self, X, y)
#     230 while not np.all(has_label) and (
#     231     self.max_iter is None or self.n_iter_ < self.max_iter
#     232 ):
#     233     self.n_iter_ += 1
# --> 234     self.base_estimator_.fit(
#     235         X[safe_mask(X, has_label)], self.transduction_[has_label]
#     236     )
#     238     # Predict on the unlabeled samples
#     239     prob = self.base_estimator_.predict_proba(X[safe_mask(X, ~has_label)])
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/svm/_base.py:251, in BaseLibSVM.fit(self, X, y, sample_weight)
#     248     print("[LibSVM]", end="")
#     250 seed = rnd.randint(np.iinfo("i").max)
# --> 251 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     252 # see comment on the other call to np.iinfo in this file
#     254 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/svm/_base.py:374, in BaseLibSVM._sparse_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     360 kernel_type = self._sparse_kernels.index(kernel)
#     362 libsvm_sparse.set_verbosity_wrap(self.verbose)
#     364 (
#     365     self.support_,
#     366     self.support_vectors_,
#     367     dual_coef_data,
#     368     self.intercept_,
#     369     self._n_support,
#     370     self._probA,
#     371     self._probB,
#     372     self.fit_status_,
#     373     self._num_iter,
# --> 374 ) = libsvm_sparse.libsvm_sparse_train(
#     375     X.shape[1],
#     376     X.data,
#     377     X.indices,
#     378     X.indptr,
#     379     y,
#     380     solver_type,
#     381     kernel_type,
#     382     self.degree,
#     383     self._gamma,
#     384     self.coef0,
#     385     self.tol,
#     386     self.C,
#     387     self.class_weight_,
#     388     sample_weight,
#     389     self.nu,
#     390     self.cache_size,
#     391     self.epsilon,
#     392     int(self.shrinking),
#     393     int(self.probability),
#     394     self.max_iter,
#     395     random_seed,
#     396 )
#     398 self._warn_from_fit_status()
#     400 if hasattr(self, "classes_"):
#
# File sklearn/svm/_libsvm_sparse.pyx:196, in sklearn.svm._libsvm_sparse.libsvm_sparse_train()
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/sparse/_compressed.py:26, in _cs_matrix.__init__(self, arg1, shape, dtype, copy)
#      23 class _cs_matrix(_data_matrix, _minmax_mixin, IndexMixin):
#      24     """base matrix class for compressed row- and column-oriented matrices"""
# ---> 26     def __init__(self, arg1, shape=None, dtype=None, copy=False):
#      27         _data_matrix.__init__(self)
#      29         if isspmatrix(arg1):
#
# KeyboardInterrupt:

# %%
#Also runed
best_C = grid.best_params_['base_estimator__C']
best_gamma = grid.best_params_['base_estimator__gamma']
best_kernel = grid.best_params_['base_estimator__kernel']
print(best_C,best_gamma, best_kernel, class_weight)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [12], line 2
#       1 #Also runed
# ----> 2 best_C = grid.best_params_['base_estimator__C']
#       3 best_gamma = grid.best_params_['base_estimator__gamma']
#       4 best_kernel = grid.best_params_['base_estimator__kernel']
#
# NameError: name 'grid' is not defined

# %%
from sklearn.svm import SVC
from sklearn.semi_supervised import SelfTrainingClassifier

# Set the best hyperparameters and set instance for base classifier
best_params = {'base_estimator__C': 100,
               'base_estimator__gamma': 0.001,
               'base_estimator__kernel': 'rbf',
               'base_estimator__class_weight': {0: 1, 1: 4}}

base_classifier = SVC(probability=True,
                      C=best_params['base_estimator__C'],
                      gamma=best_params['base_estimator__gamma'],
                      kernel=best_params['base_estimator__kernel'],
                      class_weight=best_params['base_estimator__class_weight'])

# Create a new instance of your self_training_model using your base_classifier
self_training_model_hp = SelfTrainingClassifier(base_classifier)


# Fit the model using your all labeled data to increase robustness of the model now that it has been tested
self_training_model_hp.fit(X_train, y_train)
# Out:
# SelfTrainingClassifier(base_estimator=SVC(C=100, class_weight={0: 1, 1: 4},
#                                           gamma=0.001, probability=True))

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score


predictions = self_training_model_hp.predict(X_test)
print("Classification Report:")
print(classification_report(y_test, predictions))

print("Confusion Matrix:")
print(confusion_matrix(y_test, predictions))

print("Accuracy Score:")
print(accuracy_score(y_test, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00       462
#            0       0.83      0.99      0.91      2275
#            1       0.78      0.85      0.81       140
#
#     accuracy                           0.83      2877
#    macro avg       0.54      0.61      0.57      2877
# weighted avg       0.69      0.83      0.76      2877
#
# Confusion Matrix:
# [[   0  440   22]
#  [   0 2263   12]
#  [   0   21  119]]
# Accuracy Score:
# 0.8279457768508863
# /Users/santinule/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/santinule/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/santinule/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#After testing, use all data to generate a model


best_params = {'base_estimator__C': 100,
               'base_estimator__gamma': 0.001,
               'base_estimator__kernel': 'rbf',
               'base_estimator__class_weight': {0: 1, 1: 4}}

base_classifier = SVC(probability=True,
                      C=best_params['base_estimator__C'],
                      gamma=best_params['base_estimator__gamma'],
                      kernel=best_params['base_estimator__kernel'],
                      class_weight=best_params['base_estimator__class_weight'])



# Create a new instance of your self_training_model using your base_classifier
self_training_model_robust = SelfTrainingClassifier(base_classifier)


# Fit the model using your all labeled data to increase robustness of the model now that it has been tested
self_training_model_robust.fit(X, y)
# Out:
# SelfTrainingClassifier(base_estimator=SVC(C=100, class_weight={0: 1, 1: 4},
#                                           gamma=0.001, probability=True))

# %%
from joblib import dump, load

# Save the model using joblib
dump(self_training_model_robust, '../../joblib/self_training_model_robust_ps.joblib')
# Out:
# ['../../joblib/self_training_model_robust_ps.joblib']

# %%
import joblib
# 2. Prepare your new data
# This should be in the same format (e.g., same features, same preprocessing steps, etc.) as the training data
new_data = [...]  # Replace with your new data

# 3. Use the loaded model to make predictions
predictions = loaded_model_from_joblib.predict(X)

print(predictions)

prob_df = pd.DataFrame(probabilities, columns=self_training_model_hp.classes_)

prob_df

df_with_probs = pd.concat([df, prob_df], axis=1)

df_with_probs.head(n=20)
# Out:
# [0 1 0 ... 0 0 0]
#          dsm                                               text  \
# 0   11432511                                            SUMMARY
# 1   11432511  This is a Bilingual Receptionist position with...
# 2   11432511                                ESSENTIAL FUNCTIONS
# 3   11432511  Reasonable accommodations may be made to enabl...
# 4   11432511  Responsible for communication with non-English...
# 5   11432511  Follows current protocol in place for opening ...
# 6   11432511  Greets patients in polite, prompt and helpful ...
# 7   11432511  Provides necessary instructions/directions as ...
# 8   11432511  Informs appropriate department of patient’s ar...
# 9   11432511  Completes necessary paperwork such as encounte...
# 10  11432511  Accurately uses the computer system to generat...
# 11  11432511  Updates patient information, collects co-pays,...
# 12  11432511  Scans necessary documents into patient’s chart...
# 13  11432511  Maintains a clean and current waiting area inc...
# 14  11432511  Answers telephone line and schedules according...
# 15  11432511  Books, coordinates and reschedules patient’s a...
# 16  11432511  Arranges loose work/scanned materials in date ...
# 17  11432511  Collects accurate patient balances as instruct...
# 18  11432511      Balances daily accounts accurately and timely
# 19  11432511  Completes daily chart prep accurately and timely.
#
#     previous_column_number  str_len  is_ps entity_encode  \
# 0                        2        7     -1            11
# 1                        3      415      1            11
# 2                        4       19      0            11
# 3                        5      103      0            11
# 4                        6      159      0            11
# 5                        7       68      0            11
# 6                        8       53      0            11
# 7                        9       65      0            11
# 8                       10       52      0            11
# 9                       11      111      0            11
# 10                      12       82      0            11
# 11                      13      146      0            11
# 12                      14       79      0            11
# 13                      15       75      0            11
# 14                      16      132      0            11
# 15                      17      110      0            11
# 16                      18      115      0            11
# 17                      19       75      0            11
# 18                      20       45      0            11
# 19                      21       49      0            11
#
#                                              lag_text  \
# 0                                          first line
# 1                                             SUMMARY
# 2   This is a Bilingual Receptionist position with...
# 3                                 ESSENTIAL FUNCTIONS
# 4   Reasonable accommodations may be made to enabl...
# 5   Responsible for communication with non-English...
# 6   Follows current protocol in place for opening ...
# 7   Greets patients in polite, prompt and helpful ...
# 8   Provides necessary instructions/directions as ...
# 9   Informs appropriate department of patient’s ar...
# 10  Completes necessary paperwork such as encounte...
# 11  Accurately uses the computer system to generat...
# 12  Updates patient information, collects co-pays,...
# 13  Scans necessary documents into patient’s chart...
# 14  Maintains a clean and current waiting area inc...
# 15  Answers telephone line and schedules according...
# 16  Books, coordinates and reschedules patient’s a...
# 17  Arranges loose work/scanned materials in date ...
# 18  Collects accurate patient balances as instruct...
# 19      Balances daily accounts accurately and timely
#
#                                             lag_text2  \
# 0                                         second line
# 1                                          first line
# 2                                             SUMMARY
# 3   This is a Bilingual Receptionist position with...
# 4                                 ESSENTIAL FUNCTIONS
# 5   Reasonable accommodations may be made to enabl...
# 6   Responsible for communication with non-English...
# 7   Follows current protocol in place for opening ...
# 8   Greets patients in polite, prompt and helpful ...
# 9   Provides necessary instructions/directions as ...
# 10  Informs appropriate department of patient’s ar...
# 11  Completes necessary paperwork such as encounte...
# 12  Accurately uses the computer system to generat...
# 13  Updates patient information, collects co-pays,...
# 14  Scans necessary documents into patient’s chart...
# 15  Maintains a clean and current waiting area inc...
# 16  Answers telephone line and schedules according...
# 17  Books, coordinates and reschedules patient’s a...
# 18  Arranges loose work/scanned materials in date ...
# 19  Collects accurate patient balances as instruct...
#
#                                             lag_text3  \
# 0                                          third line
# 1                                         second line
# 2                                          first line
# 3                                             SUMMARY
# 4   This is a Bilingual Receptionist position with...
# 5                                 ESSENTIAL FUNCTIONS
# 6   Reasonable accommodations may be made to enabl...
# 7   Responsible for communication with non-English...
# 8   Follows current protocol in place for opening ...
# 9   Greets patients in polite, prompt and helpful ...
# 10  Provides necessary instructions/directions as ...
# 11  Informs appropriate department of patient’s ar...
# 12  Completes necessary paperwork such as encounte...
# 13  Accurately uses the computer system to generat...
# 14  Updates patient information, collects co-pays,...
# 15  Scans necessary documents into patient’s chart...
# 16  Maintains a clean and current waiting area inc...
# 17  Answers telephone line and schedules according...
# 18  Books, coordinates and reschedules patient’s a...
# 19  Arranges loose work/scanned materials in date ...
#
#                                             lag_text4         0         1
# 0                                         fourth line  0.997412  0.002588
# 1                                          third line  0.000002  0.999998
# 2                                         second line  0.988159  0.011841
# 3                                          first line  0.996246  0.003754
# 4                                             SUMMARY  0.988165  0.011835
# 5   This is a Bilingual Receptionist position with...  0.997119  0.002881
# 6                                 ESSENTIAL FUNCTIONS  0.998230  0.001770
# 7   Reasonable accommodations may be made to enabl...  0.998656  0.001344
# 8   Responsible for communication with non-English...  0.996264  0.003736
# 9   Follows current protocol in place for opening ...  0.996896  0.003104
# 10  Greets patients in polite, prompt and helpful ...  0.997726  0.002274
# 11  Provides necessary instructions/directions as ...  0.999635  0.000365
# 12  Informs appropriate department of patient’s ar...  0.999668  0.000332
# 13  Completes necessary paperwork such as encounte...  0.999703  0.000297
# 14  Accurately uses the computer system to generat...  0.999541  0.000459
# 15  Updates patient information, collects co-pays,...  0.999015  0.000985
# 16  Scans necessary documents into patient’s chart...  0.999472  0.000528
# 17  Maintains a clean and current waiting area inc...  0.998968  0.001032
# 18  Answers telephone line and schedules according...  0.999392  0.000608
# 19  Books, coordinates and reschedules patient’s a...  0.999559  0.000441

# %%
#This code exports 

# Get the class probabilities
probabilities = self_training_model_hp.predict_proba(X)

# Convert the probabilities to a dataframe
prob_df = pd.DataFrame(probabilities, columns=self_training_model_hp.classes_)



df_with_probs = pd.concat([df, prob_df], axis=1)

df_with_probs.head(n=20)
# Out:
#          dsm                                               text  \
# 0   11432511                                            summary
# 1   11432511  bilingual Receptionist position add responsibi...
# 2   11432511                                ESSENTIAL FUNCTIONS
# 3   11432511  reasonable accommodation enable individual dis...
# 4   11432511  responsible communication non english speak pa...
# 5   11432511    follow current protocol place open close office
# 6   11432511        greets patient polite prompt helpful manner
# 7   11432511  provide necessary instruction direction need p...
# 8   11432511      inform appropriate department patient arrival
# 9   11432511  complete necessary paperwork encounter form re...
# 10  11432511  accurately use computer system generate inform...
# 11  11432511  update patient information collect co pay prov...
# 12  11432511  scan necessary document patient chart follow c...
# 13  11432511  maintain clean current wait area include read ...
# 14  11432511  answer telephone line schedule accord current ...
# 15  11432511  book coordinate reschedule patient appointment...
# 16  11432511  arrange loose work scan material date order ma...
# 17  11432511  collect accurate patient balance instruct bill...
# 18  11432511            balance daily account accurately timely
# 19  11432511        complete daily chart prep accurately timely
#
#     previous_column_number  str_len  is_ps entity_encode  \
# 0                        2        7     -1            11
# 1                        3      415      1            11
# 2                        4       19      0            11
# 3                        5      103      0            11
# 4                        6      159      0            11
# 5                        7       68      0            11
# 6                        8       53      0            11
# 7                        9       65      0            11
# 8                       10       52      0            11
# 9                       11      111      0            11
# 10                      12       82      0            11
# 11                      13      146      0            11
# 12                      14       79      0            11
# 13                      15       75      0            11
# 14                      16      132      0            11
# 15                      17      110      0            11
# 16                      18      115      0            11
# 17                      19       75      0            11
# 18                      20       45      0            11
# 19                      21       49      0            11
#
#                                              lag_text  \
# 0                                          first line
# 1                                             SUMMARY
# 2   This is a Bilingual Receptionist position with...
# 3                                 ESSENTIAL FUNCTIONS
# 4   Reasonable accommodations may be made to enabl...
# 5   Responsible for communication with non-English...
# 6   Follows current protocol in place for opening ...
# 7   Greets patients in polite, prompt and helpful ...
# 8   Provides necessary instructions/directions as ...
# 9   Informs appropriate department of patient’s ar...
# 10  Completes necessary paperwork such as encounte...
# 11  Accurately uses the computer system to generat...
# 12  Updates patient information, collects co-pays,...
# 13  Scans necessary documents into patient’s chart...
# 14  Maintains a clean and current waiting area inc...
# 15  Answers telephone line and schedules according...
# 16  Books, coordinates and reschedules patient’s a...
# 17  Arranges loose work/scanned materials in date ...
# 18  Collects accurate patient balances as instruct...
# 19      Balances daily accounts accurately and timely
#
#                                             lag_text2  \
# 0                                         second line
# 1                                                line
# 2                                             summary
# 3   bilingual Receptionist position add responsibi...
# 4                                 ESSENTIAL FUNCTIONS
# 5   reasonable accommodation enable individual dis...
# 6   responsible communication non english speak pa...
# 7     follow current protocol place open close office
# 8         greets patient polite prompt helpful manner
# 9   provide necessary instruction direction need p...
# 10      inform appropriate department patient arrival
# 11  complete necessary paperwork encounter form re...
# 12  accurately use computer system generate inform...
# 13  update patient information collect co pay prov...
# 14  scan necessary document patient chart follow c...
# 15  maintain clean current wait area include read ...
# 16  answer telephone line schedule accord current ...
# 17  book coordinate reschedule patient appointment...
# 18  arrange loose work scan material date order ma...
# 19  collect accurate patient balance instruct bill...
#
#                                             lag_text3  \
# 0                                                line
# 1                                         second line
# 2                                                line
# 3                                             summary
# 4   bilingual Receptionist position add responsibi...
# 5                                 ESSENTIAL FUNCTIONS
# 6   reasonable accommodation enable individual dis...
# 7   responsible communication non english speak pa...
# 8     follow current protocol place open close office
# 9         greets patient polite prompt helpful manner
# 10  provide necessary instruction direction need p...
# 11      inform appropriate department patient arrival
# 12  complete necessary paperwork encounter form re...
# 13  accurately use computer system generate inform...
# 14  update patient information collect co pay prov...
# 15  scan necessary document patient chart follow c...
# 16  maintain clean current wait area include read ...
# 17  answer telephone line schedule accord current ...
# 18  book coordinate reschedule patient appointment...
# 19  arrange loose work scan material date order ma...
#
#                                             lag_text4         0         1
# 0                                         fourth line  0.997412  0.002588
# 1                                          third line  0.000002  0.999998
# 2                                         second line  0.988159  0.011841
# 3                                          first line  0.996246  0.003754
# 4                                             SUMMARY  0.988165  0.011835
# 5   This is a Bilingual Receptionist position with...  0.997119  0.002881
# 6                                 ESSENTIAL FUNCTIONS  0.998230  0.001770
# 7   Reasonable accommodations may be made to enabl...  0.998656  0.001344
# 8   Responsible for communication with non-English...  0.996264  0.003736
# 9   Follows current protocol in place for opening ...  0.996896  0.003104
# 10  Greets patients in polite, prompt and helpful ...  0.997726  0.002274
# 11  Provides necessary instructions/directions as ...  0.999635  0.000365
# 12  Informs appropriate department of patient’s ar...  0.999668  0.000332
# 13  Completes necessary paperwork such as encounte...  0.999703  0.000297
# 14  Accurately uses the computer system to generat...  0.999541  0.000459
# 15  Updates patient information, collects co-pays,...  0.999015  0.000985
# 16  Scans necessary documents into patient’s chart...  0.999472  0.000528
# 17  Maintains a clean and current waiting area inc...  0.998968  0.001032
# 18  Answers telephone line and schedules according...  0.999392  0.000608
# 19  Books, coordinates and reschedules patient’s a...  0.999559  0.000441
